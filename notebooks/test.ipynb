# %%
import requests
from bs4 import BeautifulSoup

url = 'https://jobs.lever.co/ekimetrics/c62e4fd4-acd5-4860-857a-15a6797696be/apply'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find all form inputs
form_inputs = soup.find_all('input')
for input_field in form_inputs:
    print(input_field.get('name'), input_field.get('type'))
# Out:
# resume file
# name text
# email email
# phone text
# location text
# selectedLocation hidden
# org text
# cards[a6a97378-59b0-421f-a4c9-76737b41fee1][baseTemplate] hidden
# cards[a6a97378-59b0-421f-a4c9-76737b41fee1][field0] radio
# cards[a6a97378-59b0-421f-a4c9-76737b41fee1][field0] radio
# cards[cc52355f-705b-40f9-9160-c9ff7fcbf769][baseTemplate] hidden
# cards[cc52355f-705b-40f9-9160-c9ff7fcbf769][field0] radio
# cards[cc52355f-705b-40f9-9160-c9ff7fcbf769][field0] radio
# surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][baseTemplate] hidden
# surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][surveyId] hidden
#  hidden
# surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][responses][field0] checkbox
# surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][responses][field0] checkbox
# surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][responses][field0] checkbox
# surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][responses][field0] checkbox
# ...

# %%
form_inputs = [
      {
        "name": "resume",
        "label": "Resume/CV",
        "type": "file",
        "id": "resume-upload-input"
      },
      {
        "name": "name",
        "label": "Full name✱",
        "type": "text",
        "id": ""
      },
      {
        "name": "email",
        "label": "Email✱",
        "type": "email",
        "id": ""
      },
      {
        "name": "phone",
        "label": "Phone ✱",
        "type": "text",
        "id": ""
      },
      {
        "name": "location",
        "label": "Current location",
        "type": "text",
        "id": "location-input"
      },
      {
        "name": "selectedLocation",
        "label": "Current location",
        "type": "hidden",
        "id": "selected-location"
      },
      {
        "name": "org",
        "label": "Current company",
        "type": "text",
        "id": ""
      },
      {
        "name": "cards[a6a97378-59b0-421f-a4c9-76737b41fee1][baseTemplate]",
        "label": "",
        "type": "hidden",
        "id": ""
      },
      {
        "name": "cards[a6a97378-59b0-421f-a4c9-76737b41fee1][field0]",
        "type": "radio",
        "id": ""
      },
      {
        "name": "cards[a6a97378-59b0-421f-a4c9-76737b41fee1][field0]",
        "type": "radio",
        "id": ""
      },
      {
        "name": "cards[cc52355f-705b-40f9-9160-c9ff7fcbf769][baseTemplate]",
        "label": "",
        "type": "hidden",
        "id": ""
      },
      {
        "name": "cards[cc52355f-705b-40f9-9160-c9ff7fcbf769][field0]",
        "type": "radio",
        "id": ""
      },
      {
        "name": "cards[cc52355f-705b-40f9-9160-c9ff7fcbf769][field0]",
        "type": "radio",
        "id": ""
      },
      {
        "name": "comments",
        "label": "",
        "type": "textarea",
        "id": "additional-information"
      },
      {
        "name": "surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][baseTemplate]",
        "label": "",
        "type": "hidden",
        "id": ""
      },
      {
        "name": "surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][surveyId]",
        "label": "",
        "type": "hidden",
        "id": ""
      },
      {
        "name": "surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][responses][field0]",
        "type": "checkbox",
        "id": ""
      },
      {
        "name": "surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][responses][field0]",
        "type": "checkbox",
        "id": ""
      },
      {
        "name": "surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][responses][field0]",
        "type": "checkbox",
        "id": ""
      },
      {
        "name": "surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][responses][field0]",
        "type": "checkbox",
        "id": ""
      },
      {
        "name": "surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][responses][field0]",
        "type": "checkbox",
        "id": ""
      },
      {
        "name": "surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][responses][field0]",
        "type": "checkbox",
        "id": ""
      },
      {
        "name": "surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][responses][field0]",
        "type": "checkbox",
        "id": ""
      },
      {
        "name": "surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][responses][field0]",
        "type": "checkbox",
        "id": ""
      },
      {
        "name": "surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][responses][field0]",
        "type": "checkbox",
        "id": ""
      },
      {
        "name": "surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][responses][field1]",
        "type": "radio",
        "id": ""
      },
      {
        "name": "surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][responses][field1]",
        "type": "radio",
        "id": ""
      },
      {
        "name": "surveysResponses[fc802a09-b71e-40bd-a979-34722f5246c1][responses][field1]",
        "type": "radio",
        "id": ""
      },
      {
        "name": "accountId",
        "label": "",
        "type": "hidden",
        "id": ""
      },
      {
        "name": "linkedInData",
        "label": "",
        "type": "hidden",
        "id": ""
      },
      {
        "name": "origin",
        "label": "",
        "type": "hidden",
        "id": ""
      },
      {
        "name": "referer",
        "label": "",
        "type": "hidden",
        "id": ""
      },
      {
        "name": "socialReferralKey",
        "label": "",
        "type": "hidden",
        "id": ""
      },
      {
        "name": "socialSource",
        "label": "",
        "type": "hidden",
        "id": ""
      },
      {
        "name": "resumeStorageId",
        "label": "",
        "type": "hidden",
        "id": ""
      },
      {
        "name": "h-captcha-response",
        "label": "",
        "type": "hidden",
        "id": "hcaptchaResponseInput"
      },
      {
        "name": "source",
        "label": "",
        "type": "hidden",
        "id": ""
      },
      {
        "name": "consent[marketing]",
        "type": "hidden",
        "id": ""
      },
      {
        "name": "consent[marketing]",
        "type": "checkbox",
        "id": ""
      }
    ]

# %%
data = [
  {
    "tab": 1,
    "response": [
      {
        "name": "resume",
        "label": "Resume/CV",
        "type": "file",
        "id": "resume-upload-input"
      },
      {
        "name": "name",
        "label": "Full name✱",
        "type": "text",
        "id": ""
      },
      {
        "name": "email",
        "label": "Email✱",
        "type": "email",
        "id": ""
      },
      {
        "name": "phone",
        "label": "Phone ✱",
        "type": "text",
        "id": ""
      },
      {
        "name": "location",
        "label": "Current location",
        "type": "text",
        "id": "location-input"
      },
    ]
}
]

# %%
dict = {}

for input_field in data[0]["response"]:
    if input_field.get('type') == 'text' or input_field.get('type') == 'textarea':
        dict[input_field.get('name')] = input_field.get('value')

# %%
dict
# Out:
# {'name': None, 'phone': None, 'location': None}

# %%
form_request = {"user_info": """Hi, my name is Wandrille Flamant, I'm a web dev. I'm currently working at phospho ai in Paris. 
My phone number is +33 7 69 84 44 76. """,
"json_data": dict, }

# %%
form_request
# Out:
# {'user_info': "Hi, my name is Wandrille Flamant, I'm a web dev. I'm currently working at phospho ai in Paris. \nMy phone number is +33 7 69 84 44 76. ",
#  'json_data': {'name': None,
#   'phone': None,
#   'location': None,
#   'org': None,
#   'comments': None}}

# %%
import requests

# I want to test the endpoint submit on localhost:8080

url = "http://localhost:8080/form"

# I want to send a POST request
response = requests.post(
        url,
        json=form_request,  # Note: using json parameter instead of data
        headers={"Content-Type": "application/json"}
    )

# %%
response.text
# Out:
# '{"name":"Wandrille Flamant","phone":"+33 7 69 84 44 76","location":"Paris","org":"phospho ai","comments":null}'
